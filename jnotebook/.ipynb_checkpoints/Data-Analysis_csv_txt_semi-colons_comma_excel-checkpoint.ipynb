# %%
import pandas

# %%
import pandas
df = pandas.read_csv("/anaconda3/pkgs/bokeh-1.2.0-py37_0/lib/python3.7/site-packages/bokeh/sampledata/_data/auto-mpg2.csv")
df
# Out:
#      Unnamed: 0 manufacturer               model  displ  year  cyl  \
# 0             1         audi                  a4    1.8  1999    4
# 1             2         audi                  a4    1.8  1999    4
# 2             3         audi                  a4    2.0  2008    4
# 3             4         audi                  a4    2.0  2008    4
# 4             5         audi                  a4    2.8  1999    6
# 5             6         audi                  a4    2.8  1999    6
# 6             7         audi                  a4    3.1  2008    6
# 7             8         audi          a4 quattro    1.8  1999    4
# 8             9         audi          a4 quattro    1.8  1999    4
# 9            10         audi          a4 quattro    2.0  2008    4
# 10           11         audi          a4 quattro    2.0  2008    4
# 11           12         audi          a4 quattro    2.8  1999    6
# 12           13         audi          a4 quattro    2.8  1999    6
# ...

# %%
import os
os.listdir()
# Out:
# ['Data Analysis.ipynb',
#  'Untitled1.ipynb',
#  'Untitled.ipynb',
#  'testing.ipynb',
#  '.ipynb_checkpoints',
#  'employees.csv']

# %%
import pandas
df2 = pandas.read_csv("/Users/Williams/codes/python/python-mega-course-master/supermarkets.csv")
df2.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2(dir)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-6a0f345de50d> in <module>
# ----> 1 df2(dir)
#
# TypeError: 'module' object is not callable

# %%
df2.shape
# Out:
# (6, 7)

# %%
df3 = pandas.read_json("/Users/Williams/codes/python/python-mega-course-master/supermarkets.json")
df3.set_index('ID')
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df4 = pandas.read_excel("/Users/Williams/codes/python/python-mega-course-master/supermarkets.xlsx",sheet_name=0)
df4
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
import pandas
df5 = pandas.read_csv("/Users/Williams/codes/python/python-mega-course-master/supermarkets-semi-colons.txt",sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import pandas
df6 = pandas.read_csv("http://pythonhow.com/supermarkets.csv")
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df6.set_index("Address")
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df6.loc["735 Dolores St":"3995 23rd St","Country":"ID"]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas
df8 = pandas.read_json("http://pythonhow.com/supermarkets.json")
df8
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
import pandas
df8.loc['City':'ID']
# Out:
# Empty DataFrame
# Columns: [Address, City, Country, Employees, ID, Name, State]
# Index: []

# %%
df8.set_index('ID')
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df8.loc[3:5,'Country':'ID']
# Out:
#   Country  Employees  ID
# 3     USA         10   4
# 4     USA         12   5
# 5     USA         20   6

# %%
df8.iloc[3,1:4]
# Out:
# City         San Francisco
# Country                USA
# Employees               10
# Name: 3, dtype: object

# %%
df8
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df8.iloc[3,1:4]
# Out:
# City         San Francisco
# Country                USA
# Employees               10
# Name: 3, dtype: object

# %%
df8.iloc[3,2:4]
# Out:
# Country      USA
# Employees     10
# Name: 3, dtype: object

# %%
df8.iloc(2,1:3)
# Out:
#   File "<ipython-input-78-955ab8f09fdf>", line 1
#     df8.iloc(2,1:3)
#                 ^
# SyntaxError: invalid syntax

# %%
df8['continet'] = df8.shape[0]*["North America"]

# %%
df8
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State       continet
# 0          CA 94114  North America
# 1          CA 94119  North America
# 2  California 94114  North America
# 3          CA 94114  North America
# 4        California  North America
# 5          CA 94114  North America

# %%
df8['Continent'] = df8['Country'] + ","+"North America"

# %%
df8
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State       continet          Continent
# 0          CA 94114  North America  USA,North America
# 1          CA 94119  North America  USA,North America
# 2  California 94114  North America  USA,North America
# 3          CA 94114  North America  USA,North America
# 4        California  North America  USA,North America
# 5          CA 94114  North America  USA,North America

# %%
df8_t = df8.T

# %%
df8_t
# Out:
#                            0                  1                  2  \
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# Employees                  8                 15                 25
# ID                         1                  2                  3
# Name                 Madeira        Bready Shop        Super River
# State               CA 94114           CA 94119   California 94114
# continet       North America      North America      North America
# Continent  USA,North America  USA,North America  USA,North America
#
#                            3                  4                  5
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# Country                  USA                USA                USA
# ...

# %%
df8
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State       continet          Continent
# 0          CA 94114  North America  USA,North America
# 1          CA 94119  North America  USA,North America
# 2  California 94114  North America  USA,North America
# 3          CA 94114  North America  USA,North America
# 4        California  North America  USA,North America
# 5          CA 94114  North America  USA,North America

# %%
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dm=pandas.merge(left=df6,right=df8, on= 'ID')
dm
# Out:
#    ID        Address_x         City_x           State_x Country_x  \
# 0   1     3666 21st St  San Francisco          CA 94114       USA
# 1   2   735 Dolores St  San Francisco          CA 94119       USA
# 2   3      332 Hill St  San Francisco  California 94114       USA
# 3   4     3995 23rd St  San Francisco          CA 94114       USA
# 4   5  1056 Sanchez St  San Francisco        California       USA
# 5   6  551 Alvarado St  San Francisco          CA 94114       USA
#
#         Name_x  Employees_x        Address_y         City_y Country_y  \
# 0      Madeira            8     3666 21st St  San Francisco       USA
# 1  Bready Shop           15   735 Dolores St  San Francisco       USA
# 2  Super River           25      332 Hill St  San Francisco       USA
# 3   Ben's Shop           10     3995 23rd St  San Francisco       USA
# 4      Sanchez           12  1056 Sanchez St  San Francisco       USA
# 5   Richvalley           20  551 Alvarado St  San Francisco       USA
#
# ...

# %%
import geopy
dir(geopy)
# Out:
# ['ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'GeocodeFarm',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
from geopy.geocoders import Nominatim

# %%
nom=Nominatim

# %%
from geopy.geocoders import Nominatim
nom=Nominatim
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-4c6a8ff8c7cd> in <module>
#       1 from geopy.geocoders import Nominatim
#       2 nom=Nominatim
# ----> 3 nom.geocode("3995 23rd St, San Francisco, CA 94114")
#
# TypeError: geocode() missing 1 required positional argument: 'query'

# %%
nom.geocode?

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   """Entry point for launching an IPython kernel.

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="specify_your_app_name_here")

# %%
location = geolocator.geocode("175 5th Avenue NYC")

# %%
print(location.address)
# Out:
# Flatiron Building, 175, 5th Avenue, Flatiron District, Manhattan Community Board 5, Manhattan, New York County, NYC, New York, 10010, USA

# %%
print((location.latitude, location.longitude))
# Out:
# (40.7410861, -73.9896298241625)

# %%
print(location.raw)
# Out:
# {'place_id': 138642704, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 264768896, 'boundingbox': ['40.7407597', '40.7413004', '-73.9898715', '-73.9895014'], 'lat': '40.7410861', 'lon': '-73.9896298241625', 'display_name': 'Flatiron Building, 175, 5th Avenue, Flatiron District, Manhattan Community Board 5, Manhattan, New York County, NYC, New York, 10010, USA', 'class': 'tourism', 'type': 'attraction', 'importance': 0.793003315521974, 'icon': 'https://nominatim.openstreetmap.org/images/mapicons/poi_point_of_interest.p.20.png'}

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim(user_agent="specify_your_app_name_here")

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995, 23rd Street, Noe Valley, SF, California, 94114, USA, (37.7529648, -122.4317141, 0.0))

# %%
n=nom.geocode("3995 23rd St, San Francisco, CA 94114")

# %%
n.latitude
# Out:
# 37.7529648

# %%
n.longitude
# Out:
# -122.4317141

# %%
import pandas
df9 = pandas.read_csv("/Users/Williams/codes/python/python-mega-course-master/supermarkets.csv")
df9
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df9["New_Address"] = df9["Address"]+ ", " + df9["City"] + ", " + df9["State"] + ", " + df9["Country"]
df9
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                        New_Address
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df9["Coordinates"] = df9["New_Address"].apply(nom.geocode)
df9
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                        New_Address  \
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...

# %%
df9["Coordinates"]
# Out:
# 0    (3666, 21st Street, Noe Valley, SF, California...
# 1    (735, Dolores Street, Liberty Street Historic ...
# 2    (332, Hill Street, Noe Valley, SF, California,...
# 3    (3995, 23rd Street, Noe Valley, SF, California...
# 4    (1056, Sanchez Street, Noe Valley, SF, Califor...
# 5    (551, Alvarado Street, Noe Valley, SF, Califor...
# Name: Coordinates, dtype: object

# %%
df9.Coordinates
# Out:
# 0    (3666, 21st Street, Noe Valley, SF, California...
# 1    (735, Dolores Street, Liberty Street Historic ...
# 2    (332, Hill Street, Noe Valley, SF, California,...
# 3    (3995, 23rd Street, Noe Valley, SF, California...
# 4    (1056, Sanchez Street, Noe Valley, SF, Califor...
# 5    (551, Alvarado Street, Noe Valley, SF, Califor...
# Name: Coordinates, dtype: object

# %%
df9.Coordinates[0]
# Out:
# Location(3666, 21st Street, Noe Valley, SF, California, 94114, USA, (37.756488877551, -122.429343346939, 0.0))

# %%
df9.Coordinates[0].latitude
# Out:
# 37.756488877551

# %%
df9["Latitudes"] = df9["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df9["Longitudes"] = df9["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df9
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees                                        New_Address  \
# 0          8         3666 21st St, San Francisco, CA 94114, USA
# 1         15       735 Dolores St, San Francisco, CA 94119, USA
# 2         25  332 Hill St, San Francisco, California 94114, USA
# 3         10         3995 23rd St, San Francisco, CA 94114, USA
# 4         12    1056 Sanchez St, San Francisco, California, USA
# ...
